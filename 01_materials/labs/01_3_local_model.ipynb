# %% [markdown]
# # LM Studio
#
#  LM Studio is a powerful platform designed for working with large language models (LLMs) on your local machine. It provides an intuitive interface for downloading, managing, and running a wide variety of open-source LLMs.
#
# A few characteristics of LM Studio are:
#
# + With LM Studio, users can experiment with different models, customize their settings, and interact with them in real time.
# + The platform supports both CPU and GPU acceleration, making it accessible for a range of hardware configurations.
# + LM Studio is ideal for developers, researchers, and enthusiasts who want to explore LLM capabilities without relying on cloud-based solutions.
#
# You can download and install LMStudio from [lmstudio.ai](https://lmstudio.ai/).
#
# ## LM Studio API
#
# An important characteristic in LM Studio is its support for OpenAI's API:
#
# + LM Studio accepts requests on several OpenAI endpoints and returns OpenAI-like response objects ([lmstudio.ai](https://platform.openai.com/docs/guides/prompt-engineering#message-roles-and-instruction-following)).
# + This means that we can reuse our code by pointing the local API using the `base_url` parameter.

# %% [markdown]
# ## Setup LM Studio
#
# + Download and install LM Studio from [lmstudio.ai](https://lmstudio.ai/).
# + Start the application.
# + Select a model to load:
#
#     - From the developer tab, you can select a model from the top bar.
#     - Select a model, for example, any model from the Qwen3 class of models.
#     - Start the server with the control on the top-left labelled "Status: Stopped" or "Status: Running".
#
#
# <img src="./img/01_lmstudio.png" height="400">

# %% [markdown]
# With the setup above, we can point to the local server as indicated below. The API works similarly to OpenAI; however, the underlying model runs locally and was not necessarily produced by OpenAI.

# %%
from openai import OpenAI
client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")

response = client.responses.create(
    model = 'local-model',
    input = 'hello, how are you? Please introduce yourself very briefly, in one or two sentences only,' \
    'no need to explain anything else or elaborate more after your introduction. Stop after those 1 or 2 sentences',
)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1036 try:
# -> 1037     response = self._send_request(
#    1038         request,
#    1039         stream=stream or self._should_stream_response_body(request=request),
#    1040         **kwargs,
#    1041     )
#    1042 except httpx.TimeoutException as err:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_client.py:440, in OpenAI._send_request(self, request, stream, **kwargs)
#     432 @override
#     433 def _send_request(
#     434     self,
#    (...)    438     **kwargs: Unpack[HttpxSendArgs],
#     439 ) -> httpx.Response:
# --> 440     return self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_client.py:418, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     416         used_workload_identity_auth = True
# --> 418 response = super()._send_request(request, stream=stream, **kwargs)
#     419 if (
#     420     response.status_code == 401
#     421     and self._workload_identity_auth is not None
#     422     and used_workload_identity_auth
#     423     and not retried
#     424 ):
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:964, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     957 def _send_request(
#     958     self,
#     959     request: httpx.Request,
#    (...)    962     **kwargs: Unpack[HttpxSendArgs],
#     963 ) -> httpx.Response:
# --> 964     return self._client.send(request, stream=stream, **kwargs)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[1], line 4
#       1 from openai import OpenAI
#       2 client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")
#       3
# ----> 4 response = client.responses.create(
#       5     model = 'local-model',
#       6     input = 'hello, how are you? Please introduce yourself very briefly, in one or two sentences only,' \
#       7     'no need to explain anything else or elaborate more after your introduction. Stop after those 1 or 2 sentences',
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/resources/responses/responses.py:954, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     914 def create(
#     915     self,
#     916     *,
#    (...)    952     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     953 ) -> Response | Stream[ResponseStreamEvent]:
# --> 954     return self._post(
#     955         "/responses",
#     956         body=maybe_transform(
#     957             {
#     958                 "background": background,
#     959                 "context_management": context_management,
#     960                 "conversation": conversation,
#     961                 "include": include,
#     962                 "input": input,
#     963                 "instructions": instructions,
#     964                 "max_output_tokens": max_output_tokens,
#     965                 "max_tool_calls": max_tool_calls,
#     966                 "metadata": metadata,
#     967                 "model": model,
#     968                 "moderation": moderation,
#     969                 "parallel_tool_calls": parallel_tool_calls,
#     970                 "previous_response_id": previous_response_id,
#     971                 "prompt": prompt,
#     972                 "prompt_cache_key": prompt_cache_key,
#     973                 "prompt_cache_retention": prompt_cache_retention,
#     974                 "reasoning": reasoning,
#     975                 "safety_identifier": safety_identifier,
#     976                 "service_tier": service_tier,
#     977                 "store": store,
#     978                 "stream": stream,
#     979                 "stream_options": stream_options,
#     980                 "temperature": temperature,
#     981                 "text": text,
#     982                 "tool_choice": tool_choice,
#     983                 "tools": tools,
#     984                 "top_logprobs": top_logprobs,
#     985                 "top_p": top_p,
#     986                 "truncation": truncation,
#     987                 "user": user,
#     988             },
#     989             response_create_params.ResponseCreateParamsStreaming
#     990             if stream
#     991             else response_create_params.ResponseCreateParamsNonStreaming,
#     992         ),
#     993         options=make_request_options(
#     994             extra_headers=extra_headers,
#     995             extra_query=extra_query,
#     996             extra_body=extra_body,
#     997             timeout=timeout,
#     998             security={"bearer_auth": True},
#     999         ),
#    1000         cast_to=Response,
#    1001         stream=stream or False,
#    1002         stream_cls=Stream[ResponseStreamEvent],
#    1003     )
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:1072, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069         continue
#    1071     log.debug("Raising connection error")
# -> 1072     raise APIConnectionError(request=request) from err
#    1074 log.debug(
#    1075     'HTTP Response: %s %s "%i %s" %s',
#    1076     request.method,
#    (...)   1080     response.headers,
#    1081 )
#    1082 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
from IPython.display import display, Markdown

display(Markdown(response.output_text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from IPython.display import display, Markdown
#       2
# ----> 3 display(Markdown(response.output_text))
#
# NameError: name 'response' is not defined

# %% [markdown]
# We can also ask the model what type of tasks can perform and specific capabilities

# %%
from openai import OpenAI
client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")

response = client.responses.create(
    model = 'local-model',
    input = 'Please give me two examples of tasks you can perform and tell me if you can classify images',
)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1036 try:
# -> 1037     response = self._send_request(
#    1038         request,
#    1039         stream=stream or self._should_stream_response_body(request=request),
#    1040         **kwargs,
#    1041     )
#    1042 except httpx.TimeoutException as err:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_client.py:440, in OpenAI._send_request(self, request, stream, **kwargs)
#     432 @override
#     433 def _send_request(
#     434     self,
#    (...)    438     **kwargs: Unpack[HttpxSendArgs],
#     439 ) -> httpx.Response:
# --> 440     return self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_client.py:418, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     416         used_workload_identity_auth = True
# --> 418 response = super()._send_request(request, stream=stream, **kwargs)
#     419 if (
#     420     response.status_code == 401
#     421     and self._workload_identity_auth is not None
#     422     and used_workload_identity_auth
#     423     and not retried
#     424 ):
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:964, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     957 def _send_request(
#     958     self,
#     959     request: httpx.Request,
#    (...)    962     **kwargs: Unpack[HttpxSendArgs],
#     963 ) -> httpx.Response:
# --> 964     return self._client.send(request, stream=stream, **kwargs)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[3], line 4
#       1 from openai import OpenAI
#       2 client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")
#       3
# ----> 4 response = client.responses.create(
#       5     model = 'local-model',
#       6     input = 'Please give me two examples of tasks you can perform and tell me if you can classify images',
#       7 )
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/resources/responses/responses.py:954, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     914 def create(
#     915     self,
#     916     *,
#    (...)    952     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     953 ) -> Response | Stream[ResponseStreamEvent]:
# --> 954     return self._post(
#     955         "/responses",
#     956         body=maybe_transform(
#     957             {
#     958                 "background": background,
#     959                 "context_management": context_management,
#     960                 "conversation": conversation,
#     961                 "include": include,
#     962                 "input": input,
#     963                 "instructions": instructions,
#     964                 "max_output_tokens": max_output_tokens,
#     965                 "max_tool_calls": max_tool_calls,
#     966                 "metadata": metadata,
#     967                 "model": model,
#     968                 "moderation": moderation,
#     969                 "parallel_tool_calls": parallel_tool_calls,
#     970                 "previous_response_id": previous_response_id,
#     971                 "prompt": prompt,
#     972                 "prompt_cache_key": prompt_cache_key,
#     973                 "prompt_cache_retention": prompt_cache_retention,
#     974                 "reasoning": reasoning,
#     975                 "safety_identifier": safety_identifier,
#     976                 "service_tier": service_tier,
#     977                 "store": store,
#     978                 "stream": stream,
#     979                 "stream_options": stream_options,
#     980                 "temperature": temperature,
#     981                 "text": text,
#     982                 "tool_choice": tool_choice,
#     983                 "tools": tools,
#     984                 "top_logprobs": top_logprobs,
#     985                 "top_p": top_p,
#     986                 "truncation": truncation,
#     987                 "user": user,
#     988             },
#     989             response_create_params.ResponseCreateParamsStreaming
#     990             if stream
#     991             else response_create_params.ResponseCreateParamsNonStreaming,
#     992         ),
#     993         options=make_request_options(
#     994             extra_headers=extra_headers,
#     995             extra_query=extra_query,
#     996             extra_body=extra_body,
#     997             timeout=timeout,
#     998             security={"bearer_auth": True},
#     999         ),
#    1000         cast_to=Response,
#    1001         stream=stream or False,
#    1002         stream_cls=Stream[ResponseStreamEvent],
#    1003     )
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/GitHub/deploying-ai/deploying-ai-env/lib/python3.11/site-packages/openai/_base_client.py:1072, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069         continue
#    1071     log.debug("Raising connection error")
# -> 1072     raise APIConnectionError(request=request) from err
#    1074 log.debug(
#    1075     'HTTP Response: %s %s "%i %s" %s',
#    1076     request.method,
#    (...)   1080     response.headers,
#    1081 )
#    1082 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
display(Markdown(response.output_text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 display(Markdown(response.output_text))
#
# NameError: name 'response' is not defined
